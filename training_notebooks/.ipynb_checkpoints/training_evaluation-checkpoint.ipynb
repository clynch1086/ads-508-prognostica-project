# %%
# Lung Cancer Prediction using Sagemaker Training Pipeline
# Used the prepared file from S3 featues/ folder -> data_preparation_handoff.ipynb

# %% [markdown]
# # Imports & Setup

# %%
import boto3
import sagemaker
import pandas as pd
import numpy as np
import os
import io
import time
from sklearn.utils import resample
from sagemaker.inputs import TrainingInput
from sagemaker import image_uris, get_execution_role
from sklearn.metrics import (
    accuracy_score, classification_report,
    roc_auc_score, confusion_matrix
)
 
session   = sagemaker.Session()
role      = get_execution_role()
bucket    = "prognostica-cancer-project"
prefix    = "lung-cancer"
s3_client = boto3.client("s3")
 
print(f"Role   : {role}")
print(f"Bucket : {bucket}")
print(f"Region : {session.boto_region_name}")
# Out:
# Role   : arn:aws:iam::381491860224:role/LabRole
# Bucket : prognostica-cancer-project
# Region : us-east-1

# %%
# Training preprocessing

# %%
train_df = pd.read_csv("s3://prognostica-cancer-project/features/lung_train.csv")

# Encode gender
train_df["gender"] = train_df["gender"].map({"M": 1, "F": 0})

# Encode target
train_df["lung_cancer"] = (
    train_df["lung_cancer"]
    .astype(str)
    .str.strip()
    .str.upper()
    .map({"YES": 1, "NO": 0})
)

# Convert boolean age groups to integers
bool_cols = [
    "age_group_41-50",
    "age_group_51-60",
    "age_group_61-70",
    "age_group_71+"
]

for col in bool_cols:
    train_df[col] = train_df[col].astype(int)

# %%
# Balance the Training Data

# %%
df_yes = train_df[train_df.lung_cancer == 1]
df_no = train_df[train_df.lung_cancer == 0]

df_no_upsampled = resample(
    df_no,
    replace=True,
    n_samples=len(df_yes),
    random_state=42
)

balanced_df = pd.concat([df_yes, df_no_upsampled]).sample(frac=1, random_state=42)

# %%
# Save and Upload the Balanced Trainiing File

# %%
balanced_df.to_csv("lung_train_balanced.csv", index=False)

s3_client.upload_file(
    "lung_train_balanced.csv",
    bucket,
    "features/lung_train_balanced.csv"
)

# %%
# Validation Preprocessing

# %%
val_df = pd.read_csv("s3://prognostica-cancer-project/features/lung_val.csv")

val_df["gender"] = val_df["gender"].map({"M": 1, "F": 0})

val_df["lung_cancer"] = (
    val_df["lung_cancer"]
    .astype(str)
    .str.strip()
    .str.upper()
    .map({"YES": 1, "NO": 0})
)

for col in bool_cols:
    val_df[col] = val_df[col].astype(int)

val_df.to_csv("lung_val_processed.csv", index=False)

s3_client.upload_file(
    "lung_val_processed.csv",
    bucket,
    "features/lung_val_processed.csv"
)

# %%
# Define Train and Validation Paths

# %%
train_path = "s3://prognostica-cancer-project/features/lung_train_balanced.csv"
val_path = "s3://prognostica-cancer-project/features/lung_val_processed.csv"

# %%
# Create the Training Inputs Objects

# %%
train_input = TrainingInput(
    s3_data=train_path,
    content_type="text/csv"
)

val_input = TrainingInput(
    s3_data=val_path,
    content_type="text/csv"
)

# %%
# Train the Model

# %%
xgb.fit({"train": train_input, "validation": val_input})
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-04-10-23-21-25-113
# 2026-04-10 23:21:27 Starting - Starting the training job...
# 2026-04-10 23:21:41 Starting - Preparing the instances for training...
# 2026-04-10 23:22:07 Downloading - Downloading input data...
# 2026-04-10 23:22:57 Downloading - Downloading the training image......
# 2026-04-10 23:23:58 Training - Training image download completed. Training in progress.../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2026-04-10 23:24:03.548 ip-10-2-109-215.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2026-04-10 23:24:03.572 ip-10-2-109-215.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2026-04-10:23:24:03:INFO] Imported framework sagemaker_xgboost_container.training
# [2026-04-10:23:24:03:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2026-04-10:23:24:03:INFO] No GPUs detected (normal if no gpus installed)
# [2026-04-10:23:24:04:INFO] Running XGBoost Sagemaker in algorithm mode
# [2026-04-10:23:24:04:INFO] Determined 0 GPU(s) available on the instance.
# [2026-04-10:23:24:04:INFO] Determined delimiter of CSV input is ','
# [2026-04-10:23:24:04:INFO] Determined delimiter of CSV input is ','
# [2026-04-10:23:24:04:INFO] files path: /opt/ml/input/data/train
# [2026-04-10:23:24:04:INFO] Determined delimiter of CSV input is ','
# [2026-04-10:23:24:04:INFO] files path: /opt/ml/input/data/validation
# [2026-04-10:23:24:04:INFO] Determined delimiter of CSV input is ','
# [2026-04-10:23:24:04:INFO] Single node training.
# [2026-04-10:23:24:04:INFO] Train matrix has 23817 rows and 19 columns
# [2026-04-10:23:24:04:INFO] Validation matrix has 2937 rows
# [2026-04-10 23:24:04.079 ip-10-2-109-215.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2026-04-10 23:24:04.080 ip-10-2-109-215.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2026-04-10 23:24:04.081 ip-10-2-109-215.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2026-04-10 23:24:04.081 ip-10-2-109-215.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2026-04-10:23:24:04:INFO] Debug hook created from config
# [23:24:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]#011train-logloss:0.68146#011validation-logloss:0.69401
# [2026-04-10 23:24:04.155 ip-10-2-109-215.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2026-04-10 23:24:04.160 ip-10-2-109-215.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-logloss:0.67163#011validation-logloss:0.69365
# [2]#011train-logloss:0.66371#011validation-logloss:0.69435
# [3]#011train-logloss:0.65866#011validation-logloss:0.69583
# [4]#011train-logloss:0.65365#011validation-logloss:0.69622
# [5]#011train-logloss:0.64573#011validation-logloss:0.69539
# [6]#011train-logloss:0.63999#011validation-logloss:0.69593
# [7]#011train-logloss:0.63429#011validation-logloss:0.69673
# [8]#011train-logloss:0.62839#011validation-logloss:0.69756
# [9]#011train-logloss:0.62488#011validation-logloss:0.69781
# [10]#011train-logloss:0.62183#011validation-logloss:0.69847
# [11]#011train-logloss:0.61890#011validation-logloss:0.69839
# [12]#011train-logloss:0.61391#011validation-logloss:0.70047
# [13]#011train-logloss:0.61332#011validation-logloss:0.70088
# [14]#011train-logloss:0.61214#011validation-logloss:0.70042
# [15]#011train-logloss:0.60747#011validation-logloss:0.70265
# [16]#011train-logloss:0.60314#011validation-logloss:0.70403
# [17]#011train-logloss:0.59886#011validation-logloss:0.70546
# [18]#011train-logloss:0.59406#011validation-logloss:0.70787
# [175]#011train-logloss:0.38207#011validation-logloss:0.80591
# [176]#011train-logloss:0.38128#011validation-logloss:0.80659
# [177]#011train-logloss:0.38040#011validation-logloss:0.80755
# [178]#011train-logloss:0.37984#011validation-logloss:0.80823
# [179]#011train-logloss:0.37896#011validation-logloss:0.80931
# [180]#011train-logloss:0.37769#011validation-logloss:0.81000
# [181]#011train-logloss:0.37701#011validation-logloss:0.81057
# [182]#011train-logloss:0.37603#011validation-logloss:0.81188
# [183]#011train-logloss:0.37507#011validation-logloss:0.81315
# [184]#011train-logloss:0.37418#011validation-logloss:0.81375
# [185]#011train-logloss:0.37322#011validation-logloss:0.81419
# [186]#011train-logloss:0.37223#011validation-logloss:0.81436
# [187]#011train-logloss:0.37138#011validation-logloss:0.81567
# [188]#011train-logloss:0.37100#011validation-logloss:0.81604
# [189]#011train-logloss:0.37045#011validation-logloss:0.81735
# [190]#011train-logloss:0.36942#011validation-logloss:0.81723
# [191]#011train-logloss:0.36907#011validation-logloss:0.81762
# [192]#011train-logloss:0.36830#011validation-logloss:0.81798
# [193]#011train-logloss:0.36726#011validation-logloss:0.81779
# [194]#011train-logloss:0.36618#011validation-logloss:0.81858
# [195]#011train-logloss:0.36583#011validation-logloss:0.81897
# [196]#011train-logloss:0.36497#011validation-logloss:0.81986
# [197]#011train-logloss:0.36419#011validation-logloss:0.82023
# [198]#011train-logloss:0.36335#011validation-logloss:0.82099
# [199]#011train-logloss:0.36247#011validation-logloss:0.82170
#
# 2026-04-10 23:24:18 Uploading - Uploading generated training model
# 2026-04-10 23:24:37 Completed - Training job completed
# Training seconds: 150
# Billable seconds: 150

# %%
# Deploy the Model

# %%
model = Model(
    image_uri=container,
    model_data="s3://prognostica-cancer-project/output/sagemaker-xgboost-2026-04-10-23-00-50-177/output/model.tar.gz",
    role=role,
    sagemaker_session=session
)

predictor = model.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.large",
    wait=True
)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2026-04-10-23-31-40-811
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2026-04-10-23-31-41-495
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2026-04-10-23-31-41-495
# ------!

# %%
# Attach Serializer

# %%
predictor = Predictor(
    endpoint_name="sagemaker-xgboost-2026-04-10-23-31-41-495",
    sagemaker_session=session,
    serializer=CSVSerializer()
)

# %%
# Predictions

# %%
payload = X_test.to_csv(index=False, header=False)

# Get raw predictions from the endpoint
raw_preds = predictor.predict(payload)

#  Decode bytes → string
raw_preds = raw_preds.decode("utf-8")

# Convert predictions to floats
preds = np.array([
    float(x) for x in raw_preds.split("\n")
    if x.strip() != ""
])

# %%
# Convert Predictions

# %%
preds = np.array([float(x) for x in raw_preds.split("\n") if x.strip() != ""])

# %%
# Evaluate

# %%
print("Accuracy:", accuracy_score(y_test, preds > 0.5))
print("AUC:", roc_auc_score(y_test, preds))
print(confusion_matrix(y_test, preds > 0.5))
# Out:
# Accuracy: 0.5323569482288828
# AUC: 0.5010566671564786
# [[ 176  208]
#  [1165 1387]]
